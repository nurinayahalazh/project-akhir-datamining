# %% [markdown]
# # Import Library

# %%
# Library

import pandas as pd
import numpy as np
import seaborn as sns

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Supervised

# %% [markdown]
# ## 1. Business Understanding

# %% [markdown]
# **Tujuan Bisnis**
#
# Tujuan bisnis dari analisis data klaim asuransi adalah untuk membantu perusahaan asuransi dalam menentukan harga premi yang tepat untuk polis asuransi, sehingga dapat menghasilkan keuntungan yang lebih besar dan meminimalkan risiko. Analisis data juga dapat membantu perusahaan asuransi dalam menentukan area risiko yang lebih besar sehingga mereka dapat membuat strategi pemasaran yang tepat dan memberikan layanan yang lebih baik kepada pelanggan.

# %% [markdown]
# **Penjelasan Kolom**
#
# Berikut ini adalah penjelasan mengenai setiap kolom pada dataset insurance:
#
# 1. age: umur dari pemegang polis asuransi
# 2. sex: jenis kelamin dari pemegang polis asuransi (male/female)
# 3. bmi: Indeks Massa Tubuh (IMT) dari pemegang polis asuransi, yang merupakan pengukuran berat badan relatif terhadap tinggi badan
# 4. children: jumlah anak yang dimiliki oleh pemegang polis asuransi
# 5. smoker: status perokok dari pemegang polis asuransi (yes/no)
# 6. region: kawasan tempat tinggal pemegang polis asuransi (northeast, southeast, southwest, northwest)
# 7. charges: biaya premi asuransi yang harus dibayarkan oleh pemegang polis asuransi setiap tahunnya.
#
# Kolom-kolom ini berisi informasi yang dapat digunakan untuk memprediksi biaya premi asuransi yang harus dibayarkan oleh pemegang polis.

# %% [markdown]
# **Tujuan Data Mining**
#
# Perusahaan asuransi harus menetapkan harga premi yang akurat untuk polis asuransi mereka berdasarkan risiko yang dihadapi oleh setiap pelanggan. Risiko dapat bervariasi tergantung pada faktor seperti usia, jenis kelamin, kondisi kesehatan, riwayat keluarga, dan gaya hidup pelanggan. Oleh karena itu, perusahaan asuransi memerlukan analisis data yang tepat untuk menentukan harga premi yang akurat dan meminimalkan risiko.

# %% [markdown]
# **Rencana Proyek**
#
# Rencana proyek untuk dataset klaim asuransi dapat mencakup beberapa tahap seperti:
#
# Tahap 1: Eksplorasi Data - Menganalisis dan memahami dataset, mengeksplorasi hubungan antara variabel, mengidentifikasi nilai kosong atau data yang hilang, dan membersihkan data jika diperlukan.
#
# Tahap 2: Persiapan Data - Mengubah variabel kategorikal menjadi variabel numerik, membagi dataset menjadi train dan test set, dan melakukan normalisasi data jika diperlukan.
#
# Tahap 3: Model Building - Membuat model prediksi biaya kesehatan dengan menggunakan algoritma Machine Learning seperti Regresi Linear, Decision Tree, Random Forest, atau Neural Network.
#
# Tahap 4: Evaluasi Model - Mengevaluasi performa model menggunakan metrik seperti Mean Squared Error (MSE), Root Mean Squared Error (RMSE), atau Coefficient of Determination (R-squared).
#
# Tahap 5: Penyajian Hasil - Menyajikan hasil prediksi biaya kesehatan dalam bentuk visualisasi seperti grafik atau tabel untuk membantu pemahaman dan pengambilan keputusan

# %% [markdown]
# ## 2. Data Understanding

# %% [markdown]
# ### Collect Initial Data

# %% [markdown]
# Dataset pada notebook ini diperoleh dari kaggle dengan judul "[Medical Cost Personal Datasets](https://www.kaggle.com/datasets/mirichoi0218/insurance)" yang telah tersimpan pada[ Google Drive local ](https://drive.google.com/file/d/18vtHJ4xcPFpC9WvND7xPY2Ko8wBGDC-h/view?usp=share_link)

# %%
supervised = "https://drive.google.com/file/d/18vtHJ4xcPFpC9WvND7xPY2Ko8wBGDC-h/view?usp=share_link"

# Ubah jadi bentuk seperti ini
data_supervised = "https://drive.google.com/uc?id=18vtHJ4xcPFpC9WvND7xPY2Ko8wBGDC-h"

# %%
# Data collection
df_supervised = pd.read_csv(data_supervised)

# %%
df_supervised
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ### Describe Data

# %%
# Melihat informasi umum tentang dataset menggunakan method info()
df_supervised.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# **Describe Data & Column**
#
# Dataset "[Medical Cost Personal Datasets](https://www.kaggle.com/datasets/mirichoi0218/insurance)" tersebut berisi informasi tentang biaya asuransi kesehatan seseorang, dengan variabel input atau fitur seperti usia, jenis kelamin, indeks massa tubuh, jumlah anak, apakah perokok atau tidak, dan wilayah asal.
#
# Berikut ini adalah penjelasan dari masing-masing kolom di dataset tersebut:
#
# 1. **Age**: Tipe data numerik bertipe integer, mengindikasikan usia penerima asuransi dalam tahun.
# 2. **Sex**: Tipe data kategori atau faktor (categorical) dengan dua kategori, yaitu 'male' dan 'female', mengindikasikan jenis kelamin penerima asuransi.
# 3. **Bmi**: Tipe data numerik bertipe float, Indeks massa tubuh (Body Mass Index) penerima asuransi. Indeks massa tubuh dihitung sebagai berat badan (kg) dibagi dengan tinggi badan (m) pangkat dua.
# 4. **Children**: Tipe data numerik bertipe integer, mengindikasikan jumlah anak yang dimiliki penerima asuransi.
# 5. **Smoker**: Tipe data kategori atau faktor (categorical), mengindikasikan status perokok penerima asuransi.Status perokok penerima asuransi, dengan nilai 'yes' untuk perokok dan 'no' untuk bukan perokok.
# 6. **Region**: Tipe data kategori atau faktor (categorical) dengan empat kategori, yaitu 'northeast', 'northwest', 'southeast', dan 'southwest', mengindikasikan wilayah asal penerima asuransi.
# 7. **Charges**: Tipe data numerik bertipe float, mengindikasikan biaya asuransi kesehatan yang harus dibayar oleh penerima asuransi dalam setahun, dalam satuan dollar AS.

# %%
# Melihat statistik deskriptif dari dataset menggunakan method describe()
print(df_supervised.describe())
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# Dari hasil output diatas, diketahui nilai statistik deskriptif seperti jumlah, rata-rata, standar deviasi, nilai minimum, nilai kuartil, dan nilai maksimum untuk setiap kolom numerik pada dataset supervised.

# %%
# Terdapat 1338 baris dan 7 kolom pada data ini
df_supervised.shape
# Out:
# (1338, 7)

# %%
# Analisis menggunakan metode value counts
df_supervised.smoker.value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %% [markdown]
# Dari hasil output di atas, dapat diketahui bahwa terdapat 1064 penerima asuransi yang bukan perokok dan 274 penerima asuransi yang perokok dalam dataset ini.

# %%
# Melihat korelasi antara kolom numerik pada dataset menggunakan method corr()
print(df_supervised.corr())
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000
# <ipython-input-9-30e3e9ff9518>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df_supervised.corr())

# %% [markdown]
# ### Explore Data

# %% [markdown]
# #### Comparison

# %%
#@title Perbandingan jumlah pasien laki-laki dan perempuan

import seaborn as sns
import matplotlib.pyplot as plt

s = df_supervised['sex'].value_counts()
plt.pie(s, labels = s.index, autopct='%1.1f%%', shadow=True)
plt.title("Male vs Female Percentage")
# Out:
# Text(0.5, 1.0, 'Male vs Female Percentage')

# %% [markdown]
# Hasilnya adalah plot yang menunjukkan jumlah pasien laki-laki dan perempuan dalam dataset. Dari plot tersebut dapat dilihat bahwa jumlah pasien laki-laki dalam dataset sedikit lebih banyak 1% daripada pasien perempuan.

# %%
#@title Perbandingan pasien yang merokok dan tidak
sns.countplot(data=df_supervised,x="smoker")
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %% [markdown]
# Dari output nya, dapat disimpulkan bahwa pasien yang tidak merokok lebih mendominasi daripada pasien yang merokok.

# %%
#@title Perbandingan pasien yang merokok berdasarkan jenis kelamin nya
sns.countplot(data=df_supervised,x="smoker",hue="sex")
plt.show()

# %% [markdown]
# Syntax diatas akan menampilkan plot bar yang menghitung jumlah perokok dan bukan perokok berdasarkan jenis kelamin pada dataset. Sumbu-x menunjukkan variabel "smoker" (perokok atau bukan), sedangkan sumbu-y menunjukkan jumlah pengamatan. Data pada plot kemudian dibagi berdasarkan jenis kelamin, yang ditunjukkan dengan menggunakan parameter "hue" pada syntax. Plot tersebut dapat membantu kita memahami seberapa besar perbedaan jumlah perokok dan bukan perokok berdasarkan jenis kelamin pada dataset tersebut.

# %% [markdown]
# #### Distribution

# %%
#@title Histogram dari distribusi usia pada dataset
sns.histplot(data=df_supervised, x='age', bins=40)
plt.title("Age Distribution")
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %% [markdown]
# Dilihat dari output diatas, dataset ini memiliki jumlah pasien yang sangat tinggi pada rentang usia sekitar 20 tahun.

# %%
#@title Perbandingan Biaya Asuransi antara Pasien yang Merokok dan Tidak Merokok
sns.boxplot(x='smoker', y='charges', data=df_supervised)
plt.title('Perbandingan Biaya Asuransi antara Pasien yang Merokok dan Tidak Merokok')
plt.show()

# %% [markdown]
# Syntax di atas akan membuat boxplot untuk membandingkan distribusi biaya asuransi antara pasien yang merokok dan tidak merokok. Variabel x digunakan untuk menentukan variabel kategori yang akan dibandingkan, yaitu 'smoker'. Variabel y digunakan untuk menentukan variabel numerik yang akan dibandingkan, yaitu 'charges'.
#
# Hasil output dari syntax di atas adalah sebuah boxplot yang menampilkan distribusi biaya asuransi pada pasien yang merokok dan tidak merokok. Outlier pada data juga dapat dilihat dari boxplot tersebut.

# %%
#@title Plot distribusi dari variabel BMI pada dataset
sns.displot(df_supervised["bmi"],color="red",kde=True)

# %% [markdown]
# Syntax sns.displot akan menghasilkan histogram dan juga kurva estimasi densitas kernel (KDE) dari data pada kolom "bmi" di dataset.
#
# Histogram pada plot menunjukkan frekuensi kemunculan nilai-nilai pada data "bmi". Sedangkan kurva KDE menunjukkan distribusi probabilitas yang mungkin menghasilkan nilai-nilai tersebut.

# %% [markdown]
# ## 3. Data Preparation

# %% [markdown]
# ### Handling Null Values

# %% [markdown]
# Menemukan nilai null

# %%
# Melihat informasi tabel Insurance
df_supervised.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# Melihat jumlah baris data yang nilainya null
df_supervised.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Melihat nilai boolean baris data yang nilainya null
# Nilai False menunjukkan bahwa baris data tersebut tidak memiliki nilai null
# Sehingga data akan tetap digunakan untuk pemrosesan selanjutnya
df_supervised.isnull().any()
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# charges     False
# dtype: bool

# %% [markdown]
# ### Handling Duplicate Values

# %% [markdown]
# Menemukan data duplikat

# %%
# Melihat jumlah baris data yang duplikat
df_supervised.duplicated().sum()
# Out:
# 1

# %%
# Melihat record data dari baris data yang duplikat
# Terdapat jumlah 1 baris data yang duplikat
df_supervised[df_supervised.duplicated()]
# Out:
#      age   sex    bmi  children smoker     region    charges
# 581   19  male  30.59         0     no  northwest  1639.5631

# %% [markdown]
# Menghapus data duplikat

# %%
# Menghapus baris data yang duplikat dan memasukkannya kembali ke dalam variabel
df_supervised_prep = df_supervised.drop_duplicates()

# %%
# Melihat record data yang sudah bebas dari baris data duplikat
# Baris data berkurang menjadi 1337 baris data
df_supervised_prep
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %% [markdown]
# ### Handling Outliers Value

# %%
results = []

cols = df_supervised_prep.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df_supervised_prep[col].quantile(0.25)
  q3 = df_supervised_prep[col].quantile(0.75) 
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df_supervised_prep[(df_supervised_prep[col] < lower_bound) | (df_supervised_prep[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df_supervised_prep))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom     Persentase Outliers
# age                  0.000000
# bmi                  0.673149
# children             0.000000
# charges             10.396410

# %%
# List untuk menyimpan hasil
results = []

cols = df_supervised_prep.select_dtypes(include=['float64', 'int64'])


for col in cols:
    q1 = df_supervised_prep[col].quantile(0.25)
    q3 = df_supervised_prep[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5*iqr
    upper_bound = q3 + 1.5*iqr
    outliers = df_supervised_prep[(df_supervised_prep[col] < lower_bound) | (df_supervised_prep[col] > upper_bound)]
    percent_outliers = (len(outliers)/len(df_supervised_prep))*100
    if percent_outliers < 10:
      df_supervised_prep = df_supervised_prep[~((df_supervised_prep[col] > upper_bound) | (df_supervised_prep[col] < lower_bound))]
    outliers_after = df_supervised_prep[(df_supervised_prep[col] < lower_bound) | (df_supervised_prep[col] > upper_bound)]
    percent_outliers_after = (len(outliers_after)/len(df_supervised_prep))*100
    results.append({'Kolom': col, 'Persentase Outliers': percent_outliers_after})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom     Persentase Outliers
# age                  0.000000
# bmi                  0.000000
# children             0.000000
# charges             10.391566

# %% [markdown]
# ### Extract Column

# %%
avg_charges = df_supervised_prep['charges'].mean()
df_supervised_prep['charges_category'] = df_supervised_prep['charges'].apply(lambda x: 1 if x > avg_charges else 0)

# %%
df_supervised_prep.drop('charges',axis=1)
# Out:
#       age     sex     bmi  children smoker     region  charges_category
# 0      19  female  27.900         0    yes  southwest                 1
# 1      18    male  33.770         1     no  southeast                 0
# 2      28    male  33.000         3     no  southeast                 0
# 3      33    male  22.705         0     no  northwest                 1
# 4      32    male  28.880         0     no  northwest                 0
# ...   ...     ...     ...       ...    ...        ...               ...
# 1333   50    male  30.970         3     no  northwest                 0
# 1334   18  female  31.920         0     no  northeast                 0
# 1335   18  female  36.850         0     no  southeast                 0
# 1336   21  female  25.800         0     no  southwest                 0
# 1337   61  female  29.070         0    yes  northwest                 1
#
# [1328 rows x 7 columns]

# %% [markdown]
# ### Encode data

# %%
# Encode dengan dummies kolom non-numerical
# df_supervised_prep = pd.get_dummies(df_supervised_prep, columns=['sex', 'smoker', 'region'])

# %%
df_supervised_prep['sex'] = df_supervised_prep['sex'].map({'male':1,'female':0})
df_supervised_prep['smoker'] = df_supervised_prep['smoker'].map({'yes':1,'no':0})

# %%
# Menampilkan record data
df_supervised_prep
# Out:
#       age  sex     bmi  children  smoker     region      charges  \
# 0      19    0  27.900         0       1  southwest  16884.92400
# 1      18    1  33.770         1       0  southeast   1725.55230
# 2      28    1  33.000         3       0  southeast   4449.46200
# 3      33    1  22.705         0       0  northwest  21984.47061
# 4      32    1  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50    1  30.970         3       0  northwest  10600.54830
# 1334   18    0  31.920         0       0  northeast   2205.98080
# 1335   18    0  36.850         0       0  southeast   1629.83350
# 1336   21    0  25.800         0       0  southwest   2007.94500
# 1337   61    0  29.070         0       1  northwest  29141.36030
#
#       charges_category
# 0                    1
# 1                    0
# 2                    0
# 3                    1
# 4                    0
# ...                ...
# ...

# %% [markdown]
# ### Normalize data

# %%
# Normalisasi data
df_supervised_prep['age'] = (df_supervised_prep['age'] - df_supervised_prep['age'].min()) / (df_supervised_prep['age'].max() - df_supervised_prep['age'].min())
df_supervised_prep['bmi'] = (df_supervised_prep['bmi'] - df_supervised_prep['bmi'].min()) / (df_supervised_prep['bmi'].max() - df_supervised_prep['bmi'].min())
df_supervised_prep['children'] = (df_supervised_prep['children'] - df_supervised_prep['children'].min()) / (df_supervised_prep['children'].max() - df_supervised_prep['children'].min())

# %%
# Menampilkan record data
df_supervised_prep
# Out:
#            age  sex       bmi  children  smoker     region      charges  \
# 0     0.021739    0  0.387788       0.0       1  southwest  16884.92400
# 1     0.000000    1  0.578435       0.2       0  southeast   1725.55230
# 2     0.217391    1  0.553426       0.6       0  southeast   4449.46200
# 3     0.326087    1  0.219065       0.0       0  northwest  21984.47061
# 4     0.304348    1  0.419617       0.0       0  northwest   3866.85520
# ...        ...  ...       ...       ...     ...        ...          ...
# 1333  0.695652    1  0.487496       0.6       0  northwest  10600.54830
# 1334  0.000000    0  0.518350       0.0       0  northeast   2205.98080
# 1335  0.000000    0  0.678467       0.0       0  southeast   1629.83350
# 1336  0.065217    0  0.319584       0.0       0  southwest   2007.94500
# 1337  0.934783    0  0.425788       0.0       1  northwest  29141.36030
#
#       charges_category
# 0                    1
# 1                    0
# 2                    0
# ...

# %%
# Menampilkan tipe data
df_supervised_prep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1328 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               1328 non-null   float64
#  1   sex               1328 non-null   int64
#  2   bmi               1328 non-null   float64
#  3   children          1328 non-null   float64
#  4   smoker            1328 non-null   int64
#  5   region            1328 non-null   object
#  6   charges           1328 non-null   float64
#  7   charges_category  1328 non-null   int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 93.4+ KB

# %% [markdown]
# ### Format Data

# %%
df_supervised_prep = pd.get_dummies(df_supervised_prep)

# %%
from sklearn.model_selection import train_test_split
x = df_supervised_prep.drop(['charges','charges_category'],axis=1)
y = df_supervised_prep['charges_category']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
x_train
# Out:
#            age  sex       bmi  children  smoker  region_northeast  \
# 623   0.000000    1  0.570802       0.0       1                 1
# 541   0.043478    0  0.514128       0.4       0                 0
# 140   0.347826    1  0.209808       0.4       0                 1
# 1173  0.434783    1  0.431958       0.4       0                 0
# 1036  0.086957    1  0.685612       0.4       1                 0
# ...        ...  ...       ...       ...     ...               ...
# 1104  0.413043    1  0.449497       0.0       0                 0
# 1139  0.021739    0  0.536863       0.0       1                 0
# 1303  0.543478    1  0.384540       0.0       1                 0
# 867   0.847826    1  0.900942       0.2       0                 0
# 1135  0.695652    0  0.394933       0.6       0                 0
#
#       region_northwest  region_southeast  region_southwest
# 623                  0                 0                 0
# ...

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
# definisikan model KNN
clf = KNeighborsClassifier()

# definisikan hyperparameter yang ingin diuji
param_grid = {'n_neighbors': [3, 5, 7, 9]}

# inisialisasi GridSearchCV
grid_search = GridSearchCV(clf, param_grid, cv=5)

# latih model dengan GridSearchCV
grid_search.fit(x_train, y_train)

# tampilkan parameter terbaik
print("Nilai k terbaik:", grid_search.best_params_['n_neighbors'])

# tampilkan skor validasi terbaik
print("Skor validasinya:", grid_search.best_score_)
# Out:
# Nilai k terbaik: 9
# Skor validasinya: 0.8815867480383609

# %%
# ambil nilai skor validasi dari grid search
mean_scores = grid_search.cv_results_['mean_test_score']
std_scores = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']

# plot hasil dari grid search
plt.errorbar(
    [params[i]['n_neighbors'] for i in range(len(params))],
    mean_scores,
    fmt='o-'
)
plt.xlabel('Nilai K')
plt.ylabel('Skor Uji Rata-Rata')
plt.title('Hasil Validasi Silang')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Validasi silang

# %%
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# Inisialisasi model Gaussian Naive Bayes
tes = GaussianNB()

# Lakukan validasi silang dengan 5 fold
scores = cross_val_score(tes, x_train, y_train, cv=5)

# Cetak skor akurasi dari masing-masing fold
print("Skor akurasi setiap fold: ", scores)

# Cetak hasil validasi silang
print("Akurasi: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

# Train model pada data latih
tes.fit(x_train, y_train)

# Prediksi hasil pada data uji
y_pred = tes.predict(x_test)

# Hitung akurasi pada data uji
accuracy = accuracy_score(y_test, y_pred)

# Cetak akurasi pada data uji
print("Akurasi pada data uji: %0.2f" % accuracy)
# Out:
# Skor akurasi setiap fold:  [0.89247312 0.90322581 0.91397849 0.84946237 0.87027027]
# Akurasi: 0.89 (+/- 0.05)
# Akurasi pada data uji: 0.89

# %%
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score


# Inisialisasi model KNN dengan nilai k = 9
tes = KNeighborsClassifier(n_neighbors=9)

# Lakukan validasi silang dengan 5-fold cross validation
scores = cross_val_score(tes, x_train, y_train, cv=5)

# Cetak skor akurasi dari masing-masing fold
print("Skor akurasi setiap fold: ", scores)

# Cetak rata-rata skor akurasi dari seluruh fold
print("Akurasi: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

# Train model pada data latih
tes.fit(x_train, y_train)

# Prediksi hasil pada data uji
y_pred = tes.predict(x_test)

# Hitung akurasi pada data uji
accuracy = accuracy_score(y_test, y_pred)

# Cetak akurasi pada data uji
print("Akurasi pada data uji: %0.2f" % accuracy)
# Out:
# Skor akurasi setiap fold:  [0.89784946 0.88172043 0.90860215 0.84408602 0.87567568]
# Akurasi: 0.88 (+/- 0.04)
# Akurasi pada data uji: 0.89

# %%
# # Pilih kolom 'charges' untuk diubah nilainya menjadi kategori "under average" atau "above average"
# target = df_supervised_prep[['charges']]

# # Hitung rata-rata dari kolom 'charges'
# target_mean = target['charges'].mean()

# # Buat fungsi untuk mengubah nilai numerik menjadi kategori "under average" dan "above average"
# def to_category(value, target_mean):
#     if value >= target_mean:
#         return 1
#     else:
#         return 0

# # Ubah nilai pada kolom 'charges' menjadi kategori "under average" atau "above average"
# df_supervised_prep['charges'] = df_supervised_prep['charges'].apply(to_category, args=(target_mean,))

# %%
# Melihat record data
# df_supervised_prep

# %% [markdown]
# ### Normalize Data

# %%
# Normalisasi data
# df_supervised_prep['age'] = (df_supervised_prep['age'] - df_supervised_prep['age'].min()) / (df_supervised_prep['age'].max() - df_supervised_prep['age'].min())
# df_supervised_prep['bmi'] = (df_supervised_prep['bmi'] - df_supervised_prep['bmi'].min()) / (df_supervised_prep['bmi'].max() - df_supervised_prep['bmi'].min())
# df_supervised_prep['children'] = (df_supervised_prep['children'] - df_supervised_prep['children'].min()) / (df_supervised_prep['children'].max() - df_supervised_prep['children'].min())

# %%
# Menampilkan record data
# df_supervised_prep

# %%
# Menampilkan tipe data
# df_supervised_prep.info()

# %% [markdown]
# ### Export Data

# %%
# Simpan cleaned data ke file csv
df_supervised_prep.to_csv('cleaned_insurance.csv', index=False)

# %%
# Melihat cleaned data yg sudah diekspor
df = pd.read_csv('cleaned_insurance.csv')
df
# Out:
#            age  sex       bmi  children  smoker      charges  \
# 0     0.021739    0  0.387788       0.0       1  16884.92400
# 1     0.000000    1  0.578435       0.2       0   1725.55230
# 2     0.217391    1  0.553426       0.6       0   4449.46200
# 3     0.326087    1  0.219065       0.0       0  21984.47061
# 4     0.304348    1  0.419617       0.0       0   3866.85520
# ...        ...  ...       ...       ...     ...          ...
# 1323  0.695652    1  0.487496       0.6       0  10600.54830
# 1324  0.000000    0  0.518350       0.0       0   2205.98080
# 1325  0.000000    0  0.678467       0.0       0   1629.83350
# 1326  0.065217    0  0.319584       0.0       0   2007.94500
# 1327  0.934783    0  0.425788       0.0       1  29141.36030
#
#       charges_category  region_northeast  region_northwest  region_southeast  \
# 0                    1                 0                 0                 0
# ...

# %% [markdown]
# ## 4. Modelling

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Algoritma KNN

# %% [markdown]
# Data Prepare (Split Data)

# %%
# from sklearn.model_selection import train_test_split

# df = pd.read_csv('cleaned_insurance.csv')

# X = df.drop(['charges'], axis=1).values
# y = df['charges'].values
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Pre-Process

# %%
# class KNN:
#     def __init__(self, k):
#         self.k = k
        
#     def fit(self, X, y):
#         self.X_train = X
#         self.y_train = y
        
#     def predict(self, X_test):
#         predictions = []
#         for x in X_test:
#             distances = []
#             for i in range(len(self.X_train)):
#                 distance = np.sqrt(np.sum(np.square(x - self.X_train[i])))
#                 distances.append((distance, self.y_train[i]))
#             distances.sort()
#             neighbors = distances[:self.k]
#             classes = {}
#             for neighbor in neighbors:
#                 if neighbor[1] in classes:
#                     classes[neighbor[1]] += 1
#                 else:
#                     classes[neighbor[1]] = 1
#             sorted_classes = sorted(classes.items(), key=lambda x: x[1], reverse=True)
#             predictions.append(sorted_classes[0][0])
#         return predictions

# %%
class KNeighbors:
    def __init__(self, n_neighbors=None):
        self.n_neighbors = n_neighbors
        
    def fit(self, X, y):
        self.X_train = np.array(X)
        self.y_train = np.array(y)
        
    def predict(self, X_test):
        X_test = np.array(X_test)
        y_pred = np.zeros(X_test.shape[0], dtype=self.y_train.dtype)
        for i, x_test in enumerate(X_test):
            distances = np.sqrt(np.sum((self.X_train - x_test)**2, axis=1))
            indices = np.argsort(distances)[:self.n_neighbors]
            k_nearest_classes = self.y_train[indices]
            y_pred[i] = np.argmax(np.bincount(k_nearest_classes))
        return y_pred

# %% [markdown]
# Process

# %%
# Inisialisasi model KNN dengan k=5
knn = KNeighbors(n_neighbors=9)

# Train model menggunakan data train
knn.fit(x_train, y_train)

# Prediksi label pada data test
knn_pred = knn.predict(x_test)

# %%
# Menghitung akurasi model
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, knn_pred)
print("Akurasi model KNN :", accuracy)
# Out:
# Akurasi model KNN : 0.8947368421052632

# %% [markdown]
# ### Algoritma Naive Bayes

# %% [markdown]
# Data Prepare (Split Data)

# %%
# x_train = pd.get_dummies(x_train)
# x_test = pd.get_dummies(x_test)

# %%
# from sklearn.model_selection import train_test_split

# df = pd.read_csv('cleaned_insurance.csv')

# x = df.drop('charges',axis=1)
# y = df['charges']
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# Pre-Process

# %%
class GaussianNB:
    # Constructor
    def __init__(self):
        self.sigmas = dict()
        self.dispersions = dict()
        self.probs = dict()
        self.index = None
        self.targets = None
        self.columns = None
    
    def fit(self, x, y):
        # Convert x to DataFrame
        x = pd.DataFrame(x, columns=self.columns)

        # Store the original index of x
        self.index = x.index

        # Preparing sigma / dispersion dictionaries for numeric columns
        self.sigmas = {}
        self.dispersions = {}
        for column in x.select_dtypes(include=[np.number]):
            self.sigmas[column] = {}
            self.dispersions[column] = {}
            for target in y.unique():
                sample = np.array(x[y.values == target][column])
                self.sigmas[column][target] = sample.std()
                self.dispersions[column][target] = sample.mean()
                self.probs[column] = len(sample) / len(x)

        self.targets = y.unique()
        self.columns = x.columns

    # Predict method
    def predict(self, X):
        predicts = list()
        for row in X.to_numpy():
            target_prob_dict = dict()
            for target in self.targets:
                for x, column in zip(row, self.columns):
                    x = float(x)
                    sigma = self.sigmas[column][target]
                    dispersion = self.dispersions[column][target]
                    prob = self.probs[column]
                    target_prob = ((1 / np.sqrt(np.pi*sigma)) * np.exp(-( (x-dispersion)**2 / (2*sigma**2)))) * prob

                    if target not in target_prob_dict:
                        target_prob_dict[target] = target_prob
                    else:
                        target_prob_dict[target] *= target_prob
                        
            # Get the predicted class based on the highest probability
            predicted_class = max(target_prob_dict, key=target_prob_dict.get)
            predicts.append(predicted_class)
        
        return predicts
    
    def print(self):
        print("Sigmas:")
        for column in self.sigmas:
            print(f"\t{self.columns[column]}")

# %% [markdown]
# Process

# %%
# definisikan model Naive Bayes
gnb = GaussianNB()

# latih model Naive Bayes
gnb.fit(x_train, y_train)

# evaluasi performa model menggunakan data uji
gnb_pred = gnb.predict(x_test)

# %%
# Menghitung akurasi model
accuracy = accuracy_score(y_test, gnb_pred)
print("Akurasi model Naive Bayes :", accuracy)
# Out:
# Akurasi model Naive Bayes : 0.8872180451127819

# %% [markdown]
# ### Algoritma C4.5

# %% [markdown]
# Data Prepare

# %%
# Import library yang dibutuhkan
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
# # Membaca dataset
# insurance_df = pd.read_csv("cleaned_insurance.csv")

# %% [markdown]
# Process

# %%
# inisialisasi model Decision Tree Classifier
dtc = DecisionTreeClassifier()

# train model pada data train
dtc.fit(x_train, y_train)

# evaluasi model pada data test
dtc_pred = dtc.predict(x_test)

# %%
# Menghitung akurasi model
accuracy = accuracy_score(y_test, dtc_pred)
print("Akurasi model C4.5 :", accuracy)
# Out:
# Akurasi model C4.5 : 0.8571428571428571

# %% [markdown]
# ## 5. Evaluation

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_auc_score, roc_curve, f1_score

# buat list model dan nama model
models = [knn, gnb, dtc]
model_names = ['K-Nearest Neighbor', 'Gaussian Naive Bayes', 'Decision Tree Classifier']

# inisialisasi list untuk menyimpan hasil evaluasi
acc_scores = []
pre_scores = []
rec_scores = []
f1_scores = []
roc_scores = []

# buat figure dan axes untuk menampilkan visualisasi
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(20, 10))

# loop untuk setiap model
for i, model in enumerate(models):
    # prediksi target variabel pada data uji
    y_pred = model.predict(x_test)

    # hitung confusion matrix
    cm = confusion_matrix(y_test, y_pred)

    # hitung nilai roc-auc
    roc = roc_auc_score(y_test, y_pred)

    # hitung false positive rate (fpr) dan true positive rate (tpr) untuk kurva roc
    fpr, tpr, _ = roc_curve(y_test, y_pred)

    # tampilkan kurva roc
    roc_display = axes[0,i].plot(fpr, tpr, color='darkorange', label='ROC curve (area = %0.2f)' % roc)
    roc_display = axes[0,i].plot([0, 1], [0, 1], color='navy', linestyle='--')
    roc_display = axes[0,i].set_xlim([0.0, 1.0])
    roc_display = axes[0,i].set_ylim([0.0, 1.05])
    roc_display = axes[0,i].set_xlabel('False Positive Rate')
    roc_display = axes[0,i].set_ylabel('True Positive Rate')
    roc_display = axes[0,i].set_title('ROC Curve - ' + model_names[i])
    roc_display = axes[0,i].legend(loc="lower right")

    # tambahkan baris kosong
    fig.subplots_adjust(hspace=0.3)

    # tampilkan confusion matrix
    cm_display = ConfusionMatrixDisplay(cm).plot(ax=axes[1,i], cmap='Purples')
    cm_display.ax_.set_title(model_names[i])

    # hitung true negative, false positive, false negative, true positive
    tn, fp, fn, tp = cm.ravel()

    # hitung precision, recall, dan f1-score
    ac = (tp + tn) / (tp + fp + fn + tn)
    pr = tp / (tp + fp)
    rc = tp / (tp + fn)
    f1 = f1_score(y_test, y_pred)

    # simpan hasil evaluasi pada list
    acc_scores.append(ac * 100)
    pre_scores.append(pr * 100)
    rec_scores.append(rc * 100)
    f1_scores.append(f1 * 100)
    roc_scores.append(roc * 100)

# tampilkan visualisasi
plt.show()

# buat dataframe dari hasil evaluasi
df_eval = pd.DataFrame({'': model_names,
                        'Accuracy (%)': acc_scores,
                        'Precision (%)': pre_scores,
                        'Recall (%)': rec_scores,
                        'F1-Score (%)': f1_scores,
                        'ROC-AUC (%)': roc_scores})

# set index dataframe menjadi kosong
df_eval = df_eval.set_index('')

# ubah nama axis pada index dan kolom
df_eval = df_eval.rename_axis(None, axis=0).rename_axis('', axis=1)

# menampilkan dataframe dengan style untuk highlight nilai tertinggi
def highlight_max(s):
    is_max = s == s.max()
    return ['background-color: green' if v else '' for v in is_max]

df_eval = df_eval.style.apply(highlight_max, axis=0)

# tampilkan dataframe
display(df_eval)
# Out:
# <style type="text/css">
# #T_8ffde_row0_col0, #T_8ffde_row0_col1, #T_8ffde_row0_col3, #T_8ffde_row1_col1, #T_8ffde_row2_col2, #T_8ffde_row2_col4 {
#   background-color: green;
# }
# </style>
# <table id="T_8ffde" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_8ffde_level0_col0" class="col_heading level0 col0" >Accuracy (%)</th>
#       <th id="T_8ffde_level0_col1" class="col_heading level0 col1" >Precision (%)</th>
#       <th id="T_8ffde_level0_col2" class="col_heading level0 col2" >Recall (%)</th>
#       <th id="T_8ffde_level0_col3" class="col_heading level0 col3" >F1-Score (%)</th>
#       <th id="T_8ffde_level0_col4" class="col_heading level0 col4" >ROC-AUC (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ffde_level0_row0" class="row_heading level0 row0" >K-Nearest Neighbor</th>
#       <td id="T_8ffde_row0_col0" class="data row0 col0" >89.473684</td>
# ...

# %% [markdown]
# ## 6. Deployment

# %% [markdown]
# Berdasarkan perhitungan dari ketiga algoritma yang digunakan, dapat disimpulkan bahwa algoritma **K-Nearest Neighbor** menjadi algoritma yang paling efektif diantara algoritma lainnya. Hal tersebut dapat dilihat dari hasil akurasi tertinggi pada nilai 89%.

# %% [markdown]
# # Unsupervised

# %% [markdown]
# ## 1. Business Understanding

# %% [markdown]
# **Tujuan Bisnis**
#
# Tujuan bisnis dari proyek ini adalah untuk mengelompokkan wine berdasarkan atribut-atribut fisik dan kimia yang dimilikinya, dengan tujuan untuk memahami karakteristik masing-masing kelompok wine dan meningkatkan pemahaman tentang faktor-faktor yang mempengaruhi kualitas wine.

# %% [markdown]
# **Situasi Bisnis**
#
# Wine Quality Dataset merupakan dataset publik yang berisi informasi tentang kualitas wine merah dan putih berdasarkan sifat fisik dan kimia. Tujuan dari proyek ini adalah untuk mengelompokkan wine ke dalam kelompok-kelompok berdasarkan atribut-atribut yang dimilikinya. Kelompok-kelompok ini dapat memberikan wawasan tentang karakteristik wine yang berbeda dan memfasilitasi pemahaman tentang faktor-faktor yang mempengaruhi kualitas wine.

# %% [markdown]
# **Tujuan Data Mining**
#
# Tujuan dari analisis data ini adalah untuk melakukan clustering data pada dataset Wine Quality dan mengelompokkan wine ke dalam kelompok-kelompok berdasarkan atribut-atribut yang dimilikinya. Hal ini dilakukan untuk memahami karakteristik masing-masing kelompok wine dan meningkatkan pemahaman tentang faktor-faktor yang mempengaruhi kualitas wine.

# %% [markdown]
# **Rencana Proyek**
#
# 1. Tahap Pertama: Memahami Tujuan Bisnis dan Situasi Bisnis
# Pada tahap ini, tim proyek akan memahami tujuan bisnis dan situasi bisnis yang melatarbelakangi proyek ini. Mereka akan berbicara dengan pihak perusahaan yang meminta proyek ini untuk memahami tujuan mereka dan situasi bisnis yang dihadapi.
# 2. Tahap Kedua: Memahami Data
# Pada tahap ini, tim proyek akan memahami dataset Wine Quality yang akan digunakan dalam proyek ini. Mereka akan mengevaluasi dan mengekstrak data yang dibutuhkan dari dataset dan mengidentifikasi atribut-atribut yang berkontribusi terhadap kualitas wine.
# 3. Tahap Ketiga: Mempersiapkan Data
# Pada tahap ini, tim proyek akan membersihkan dan mempersiapkan data yang akan digunakan dalam analisis cluster. Mereka akan melakukan preprocessing data seperti menghapus data yang hilang atau duplikat, melakukan transformasi pada data, dan melakukan normalisasi pada data jika diperlukan.
# 4. Tahap Keempat: Melakukan Analisis Cluster
# Pada tahap ini, tim proyek akan melakukan analisis cluster pada dataset Wine Quality. Mereka akan menggunakan teknik clustering seperti K-Means atau Hierarchical Clustering untuk mengidentifikasi kelompok-kelompok wine yang memiliki kualitas serupa berdasarkan atribut-atribut fisik dan kimia yang dimilikinya.
# 5. Tahap Kelima: Menafsirkan Hasil Analisis
# Pada tahap ini, tim proyek akan menafsirkan hasil analisis cluster dan mengidentifikasi kelompok-kelompok wine yang memiliki kualitas serupa. Mereka akan membuat visualisasi dan laporan hasil analisis untuk membantu perusahaan memahami karakteristik wine berkualitas.
# 6. Tahap Keenam: Menerapkan Hasil Analisis
# Pada tahap ini, perusahaan akan menerapkan hasil analisis cluster untuk meningkatkan kualitas produksi wine mereka.

# %% [markdown]
# ## 2. Data Understanding

# %% [markdown]
# ### Collect Initial Data

# %% [markdown]
# Dataset pada notebook ini diperoleh dari kaggle dengan judul "[Wine Quality Dataset](https://www.kaggle.com/datasets/yasserh/wine-quality-dataset?select=WineQT.csv)" yang telah tersimpan pada[ Google Drive local ](https://drive.google.com/file/d/1RNRiDgl4VtDAXe0F73Y5Lt-7iV9uSqmR/view?usp=share_link )

# %%
unsupervised = "https://drive.google.com/file/d/1RNRiDgl4VtDAXe0F73Y5Lt-7iV9uSqmR/view?usp=share_link"

# Ubah jadi bentuk seperti ini
data_unsupervised = "https://drive.google.com/uc?id=1RNRiDgl4VtDAXe0F73Y5Lt-7iV9uSqmR"

# %%
df_unsupervised = pd.read_csv(data_unsupervised)

# %%
df_unsupervised
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [markdown]
# ### Describe Data

# %%
# Melihat jumlah baris dan kolom
print(df_unsupervised.shape)
# Out:
# (1143, 13)

# %%
# Melihat tipe data setiap kolom
print(df_unsupervised.dtypes)
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
# Melihat informasi umum tentang dataset menggunakan method info()
df_unsupervised.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %% [markdown]
# Dataset Wine Quality yang terdapat di "[Wine Quality Dataset](https://www.kaggle.com/datasets/yasserh/wine-quality-dataset?select=WineQT.csv)" adalah kumpulan data yang berisi informasi tentang kualitas wine merah dan putih. Dataset ini memiliki satu file CSV yang berisi 4898 baris data. Setiap baris data mengandung informasi tentang sifat fisik dan kimia dari setiap sampel wine, serta kualitasnya yang dinilai oleh sekelompok ahli.
#
#
# Adapun penjelasan kolom ialah sebagai berikut :
#
# 1. fixed acidity: kandungan asam dalam angka tetap
# 2. volatile acidity: kandungan asam dalam bentuk gas
# 3. citric acid: kandungan asam sitrat
# 4. residual sugar: jumlah gula yang tersisa setelah fermentasi selesai
# 5. chlorides: kandungan garam dalam angka tetap
# 6. free sulfur dioxide: jumlah sulfur dioksida yang tersedia dalam bentuk bebas
# 7. total sulfur dioxide: jumlah sulfur dioksida dalam bentuk total
# 8. density: berat jenis wine
# 9. pH: tingkat keasaman
# 10. sulphates: kandungan sulfat
# 11. alcohol: persentase alkohol dalam wine
# 12. quality: skor kualitas wine (0-10)
# 13. Id : nomor unik dari wine
#
#
# Dalam dataset ini, terdapat beberapa tipe data yang berbeda, yaitu:
#
# 1. float: fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free suldur dioxide, total sulfur dioxide, density, pH, sulphates, dan alcohol.
# 2. int: quality dan Id.

# %%
# Melihat statistik deskriptif data
print(df_unsupervised.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
# Menampilkan 5 baris awal dataset
df_unsupervised.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %% [markdown]
# ### Explore Data

# %%
# Melihat distribusi data pada setiap kolom menggunakan histogram
df_unsupervised.hist(figsize=(10,10))
plt.show()

# %%
# Melihat hubungan antara alcohol dan quality menggunakan scatter plot
plt.scatter(df_unsupervised['alcohol'], df_unsupervised['quality'])
plt.xlabel('Alcohol')
plt.ylabel('Quality')
plt.show()

# %%
# Melihat hubungan antara volatile acidity dan quality menggunakan scatter plot
plt.scatter(df_unsupervised['volatile acidity'], df_unsupervised['quality'])
plt.xlabel('Volatile Acidity')
plt.ylabel('Quality')
plt.show()

# %% [markdown]
# ## 3. Data Preparation

# %% [markdown]
# ### Handling Null Values

# %% [markdown]
# Menemukan nilai null

# %%
# Melihat informasi tabel
df_unsupervised.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
# Melihat jumlah baris data yang nilainya null
df_unsupervised.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
# Melihat nilai boolean baris data yang nilainya null
# Nilai False menunjukkan bahwa baris data tersebut aman dari nilai null
# Sehingga dataset akan digunakan untuk proses selanjutnya
df_unsupervised.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# Id                      False
# dtype: bool

# %%
# Visualisasi baris data yang nilainya null
sns.heatmap(df_unsupervised.isnull(), yticklabels=False, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Handling Duplicate Values

# %% [markdown]
# Menemukan data duplikat

# %%
# Melihat jumlah baris data yang duplikat
df_unsupervised.duplicated().sum()
# Out:
# 0

# %%
# Melihat record data dari baris data yang duplikat
# Tidak terdapat baris yang duplikat
# Sehingga dataset akan digunakan untuk proses selanjutnya
df_unsupervised[df_unsupervised.duplicated()]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality, Id]
# Index: []

# %% [markdown]
# ###Handling Outlier Values

# %%
results = []

cols = df_unsupervised.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df_unsupervised[col].quantile(0.25)
  q3 = df_unsupervised[col].quantile(0.75) 
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df_unsupervised[(df_unsupervised[col] < lower_bound) | (df_unsupervised[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df_unsupervised))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                 Persentase Outliers
# fixed acidity                    3.849519
# volatile acidity                 1.224847
# citric acid                      0.087489
# residual sugar                   9.623797
# chlorides                        6.736658
# free sulfur dioxide              1.574803
# total sulfur dioxide             3.499563
# density                          3.149606
# pH                               1.749781
# sulphates                        3.762030
# alcohol                          1.049869
# quality                          1.924759
# Id                               0.000000

# %%
# List untuk menyimpan hasil
results = []

cols = df_unsupervised.select_dtypes(include=['float64', 'int64'])


for col in cols:
    q1 = df_unsupervised[col].quantile(0.25)
    q3 = df_unsupervised[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5*iqr
    upper_bound = q3 + 1.5*iqr
    outliers = df_unsupervised[(df_unsupervised[col] < lower_bound) | (df_unsupervised[col] > upper_bound)]
    percent_outliers = (len(outliers)/len(df_unsupervised))*100
    if percent_outliers < 10:
      df_unsupervised = df_unsupervised[~((df_unsupervised[col] > upper_bound) | (df_unsupervised[col] < lower_bound))]
    outliers_after = df_unsupervised[(df_unsupervised[col] < lower_bound) | (df_unsupervised[col] > upper_bound)]
    percent_outliers_after = (len(outliers_after)/len(df_unsupervised))*100
    results.append({'Kolom': col, 'Persentase Outliers': percent_outliers_after})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                 Persentase Outliers
# fixed acidity                         0.0
# volatile acidity                      0.0
# citric acid                           0.0
# residual sugar                        0.0
# chlorides                             0.0
# free sulfur dioxide                   0.0
# total sulfur dioxide                  0.0
# density                               0.0
# pH                                    0.0
# sulphates                             0.0
# alcohol                               0.0
# quality                               0.0
# Id                                    0.0

# %%
# Hasil drop disimpan di variabel baru
df_unsupervised_prep = df_unsupervised

# %%
# Menampilkan record data dari data yang sudah dibersihkan
df_unsupervised_prep
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
# Menampilkan informasi dataset
df_unsupervised_prep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 787 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         787 non-null    float64
#  1   volatile acidity      787 non-null    float64
#  2   citric acid           787 non-null    float64
#  3   residual sugar        787 non-null    float64
#  4   chlorides             787 non-null    float64
#  5   free sulfur dioxide   787 non-null    float64
#  6   total sulfur dioxide  787 non-null    float64
#  7   density               787 non-null    float64
#  8   pH                    787 non-null    float64
#  9   sulphates             787 non-null    float64
#  10  alcohol               787 non-null    float64
#  11  quality               787 non-null    int64
#  12  Id                    787 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 86.1 KB

# %% [markdown]
# ### Transform Data

# %%
# Menyisakan kolom yang dipakai
df_unsupervised_prep = df_unsupervised_prep.drop(columns=['Id'])

# %%
# Menampilkan record data
df_unsupervised_prep
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
# Menampilkan informasi data
df_unsupervised_prep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 787 entries, 0 to 1142
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         787 non-null    float64
#  1   volatile acidity      787 non-null    float64
#  2   citric acid           787 non-null    float64
#  3   residual sugar        787 non-null    float64
#  4   chlorides             787 non-null    float64
#  5   free sulfur dioxide   787 non-null    float64
#  6   total sulfur dioxide  787 non-null    float64
#  7   density               787 non-null    float64
#  8   pH                    787 non-null    float64
#  9   sulphates             787 non-null    float64
#  10  alcohol               787 non-null    float64
#  11  quality               787 non-null    int64
# dtypes: float64(11), int64(1)
# memory usage: 79.9 KB

# %% [markdown]
# ### Export Data

# %%
# Simpan cleaned data ke file csv
df_unsupervised_prep.to_csv('cleaned_WineQT.csv', index=False)

# %%
# Melihat cleaned data yg sudah diekspor
df = pd.read_csv('cleaned_WineQT.csv')
df
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4             0.700         0.00             1.9      0.076
# 1              7.8             0.880         0.00             2.6      0.098
# 2              7.8             0.760         0.04             2.3      0.092
# 3             11.2             0.280         0.56             1.9      0.075
# 4              7.4             0.700         0.00             1.9      0.076
# ..             ...               ...          ...             ...        ...
# 782            6.3             0.510         0.13             2.3      0.076
# 783            6.8             0.620         0.08             1.9      0.068
# 784            6.2             0.600         0.08             2.0      0.090
# 785            5.9             0.550         0.10             2.2      0.062
# 786            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [markdown]
# ## 4. Modelling

# %% [markdown]
# ### Pre-Processing

# %%
# Untuk Clustering
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering,KMeans,AffinityPropagation,Birch

# Untuk scalling dan normalisasi
from sklearn.preprocessing import StandardScaler

# Metric Pengukuran
# sumber : https://towardsdatascience.com/performance-metrics-in-machine-learning-part-3-clustering-d69550662dc6
from sklearn.metrics import silhouette_score,calinski_harabasz_score,davies_bouldin_score

# %%
# PreProcessing
# Encoding DataTraining
X_train = pd.get_dummies(df_unsupervised_prep,drop_first=True)

# %%
# Creating a class to handle clustering
class Cluster:
    
    # Pada constructor terjadi beberapa proses
    # 1. Membuat normalisasi data
    
    def __init__(self,train):
        self.train = train
        self.scaled = StandardScaler().fit_transform(self.train)
        self.clusters = None
        self.name = None
        self._label = None

    # Method apply adalah fungsi kedua yang harus dijalankan
    # Method apply akan menerima argumen tambahan sebagai argumen untuk 
    # algoritma cluster yang akan digunakan
    def apply(self,cluster_algo,**kwargs):
        agg_cluster = cluster_algo(**kwargs)


        self.clusters = agg_cluster.fit(self.scaled) #Set Value
        self._label = self.clusters.labels_ #Set value

        # Mengambil nama algoritma clusternya
        self.name = type(self.clusters).__name__

        return self
    
    # Df untuk membuat dataframe
    def df_unsupervised_prep(self,normalized=False):

        if normalized:
            X = pd.DataFrame(self.scaled,columns=self.train.columns)
        else:
            X = self.train.copy(deep=True)
        
        X["Cluster"] = self._label
        X["Cluster"] = X['Cluster'].astype(object)

        return X
    # Untuk Mendapatkan cluster ke N
    def get_cluster(self,n,normalized=False):
        df_unsupervised_prep = self.df_unsupervised_prep(normalized)
        
        return df_unsupervised_prep[df_unsupervised_prep["Cluster"] == n]

    # Plot untuk membuat scatterplot 
    def plot(self,X,Y,normalized=False):
        return px.scatter(self.df_unsupervised_prep(normalized), x=X, y=Y, color="Cluster")

    # Plot 3d untuk membuat scatterplot 3d
    def plot_3d(self,X,Y,Z,normalized=False):
        return px.scatter_3d(self.df_unsupervised_prep(normalized), x=X, y=Y,z=Z, color="Cluster")

    # menggunakan decorator property untuk mengonversi method menjadi property
    @property
    def metric(self): #Method ini berfungsi untuk mengambil hasil pengukuran berdasrkan metric ...
        label = self._label
        # Ini metric yang digunakan 'silhouette_score', 'calinski_harabasz_score', 'davies_bouldin_score'
        
        return [silhouette_score(self.scaled,label),davies_bouldin_score(self.scaled,label),calinski_harabasz_score(self.scaled,label)]

# %%
sse = [] #Daftar SSE
K = range(1,30) #Banyak Cluster hingga 30
# Perulangan hingga 30 Cluster
for k in K:
    kmeans = KMeans(n_clusters= k,random_state=42).fit(X_train)
    #Mendapatkan SSE dan append ke list sse
    sse.append(kmeans.inertia_)

# Membuat plot K terhadap SSE
plt.plot(K,sse, "bx-")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# ### Processing

# %% [markdown]
# #### KMeans

# %%
# Pertama-tama kita perlu menerapkan algoritma KMeans kedalam kelas Cluster
kmeans = Cluster(X_train).apply(KMeans,n_clusters=5,random_state=42) #n_cluster adalah banyak clusternya
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Untuk menampilkan dataframe 
kmeans.df_unsupervised_prep().head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality Cluster
# 0      9.4        5       2
# 1      9.8        5       4
# ...

# %%
kmeans.df_unsupervised_prep()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
# Menampilkan plot berdasarkan dataframe dan 3 variabel x,y,z
kmeans.plot_3d('density', 'pH', 'alcohol')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### AgglomerativeClustering

# %%
# Pertama-tama kita perlu menerapkan algoritma KMeans kedalam kelas Cluster
Agg = Cluster(X_train).apply(AgglomerativeClustering,n_clusters=5)

# %%
Agg.df_unsupervised_prep().head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality Cluster
# 0      9.4        5       1
# 1      9.8        5       0
# ...

# %%
Agg.df_unsupervised_prep()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
# Plot cluster yang diperoleh
Agg.plot_3d('density', 'pH', 'alcohol')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Birch

# %%
# Pertama-tama kita perlu menerapkan algoritma KMeans kedalam kelas Cluster
br = Cluster(X_train).apply(Birch,n_clusters=5)

# %%
# Menampilkan hasil cluster dalam bentuk dataframe
br.df_unsupervised_prep().head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality Cluster
# 0      9.4        5       1
# 1      9.8        5       0
# ...

# %%
# Menampilkan hasil cluster dalam bentuk dataframe
br.df_unsupervised_prep()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
# Scatter plot cluster tersebut
br.plot_3d('density', 'pH', 'alcohol', True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 5. Evaluation

# %% [markdown]
# ### Metric Pengukuran

# %%
# Mengumpulkan Algorita Apa Saca yang dipakai
algos = [Agg,kmeans,br]

# Untuk menampung hasil metrik (bentuk list dari list metrics ini adalah nested list)
metrics = [i.metric for i in algos]

# Nama dari setiap algo menjadi indexnya
index = [i.name for i in algos]

# Penamaan Kolmnya
df_metric = pd.DataFrame(metrics,index=index,columns=['silhouette_score', 'calinski_harabasz_score', 'davies_bouldin_score'])

# %%
df_metric
# Out:
#                          silhouette_score  calinski_harabasz_score  \
# AgglomerativeClustering          0.122657                 2.009042
# KMeans                           0.148192                 1.817063
# Birch                            0.123791                 1.945603
#
#                          davies_bouldin_score
# AgglomerativeClustering            109.719136
# KMeans                             126.162792
# Birch                              106.968637

# %%
# https://stackoverflow.com/questions/28075699/coloring-cells-in-pandas
best = [
    df_metric.iloc[:,0].max() # Makin Tinggi Nilai silhoutte makin bagus
    ,df_metric.iloc[:,1].max(), # Makin Tinggi Nilai CH makin bagus
    df_metric.iloc[:,2].min()
    ] # Makin rendah nilai David Bouldin makin bagus

#Ini untuk conditional formatting
def _color_green(val):
    if val in best:
        return 'background-color: green; color:white'
    return 'backround-color:white'

# %%
# Menampilkan tabel setelah dilakukan contional formatting
df_metric.style.applymap(_color_green)
# Out:
# <style type="text/css">
# #T_317be_row0_col0, #T_317be_row0_col2, #T_317be_row1_col1, #T_317be_row1_col2, #T_317be_row2_col0, #T_317be_row2_col1 {
#   backround-color: white;
# }
# #T_317be_row0_col1, #T_317be_row1_col0, #T_317be_row2_col2 {
#   background-color: green;
#   color: white;
# }
# </style>
# <table id="T_317be" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_317be_level0_col0" class="col_heading level0 col0" >silhouette_score</th>
#       <th id="T_317be_level0_col1" class="col_heading level0 col1" >calinski_harabasz_score</th>
#       <th id="T_317be_level0_col2" class="col_heading level0 col2" >davies_bouldin_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_317be_level0_row0" class="row_heading level0 row0" >AgglomerativeClustering</th>
#       <td id="T_317be_row0_col0" class="data row0 col0" >0.122657</td>
#       <td id="T_317be_row0_col1" class="data row0 col1" >2.009042</td>
# ...

# %% [markdown]
# Berdasarkan pengukuran diatas ditemukan bahwa model **Birch** merupakan algoritma yang cukup ideal untuk pengukuran ini. Hal tersebut dapat dilihat pada nilai davies bouldin score terkecil diantara algoritma yang lain.

# %% [markdown]
# ### Analisa Cluster

# %%
# Pertama kita perlu membuat fungsi plot untuk plotting cluster
def plot_cluster(cluster_df):
    plot, ax = plt.subplots(2,4,figsize=(30,7),constrained_layout = True)
    sns.countplot(data=cluster_df,x="quality",ax=ax[1][3])
    for i,col in enumerate(cols):
        sns.histplot(data=cluster_df,x=col,ax=ax[0][i],kde=True)
        sns.boxplot(data=cluster_df,x=col,ax=ax[1][i])

# %%
# Kolom yang berisi numerikkal
cols = ["density","pH","alcohol"]

# %%
# Membuat List Tiap Cluster yang ada
cluster1 = br.get_cluster(0)
cluster2 = br.get_cluster(1)
cluster3 = br.get_cluster(2)
cluster4 = br.get_cluster(3)
cluster5 = br.get_cluster(4)

# %% [markdown]
# #### Cluster 1

# %%
# Menampilkan deskripsi statistik dari cluster 1
cluster1.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count     242.000000        242.000000   242.000000      242.000000
# mean        8.042149          0.536364     0.245041        2.303719
# std         0.979139          0.141319     0.151647        0.442745
# min         6.200000          0.200000     0.000000        1.200000
# 25%         7.300000          0.430000     0.120000        2.000000
# 50%         7.800000          0.550000     0.240000        2.300000
# 75%         8.700000          0.627500     0.320000        2.600000
# max        11.300000          0.935000     0.640000        3.400000
#
#         chlorides  free sulfur dioxide  total sulfur dioxide     density  \
# count  242.000000           242.000000            242.000000  242.000000
# mean     0.084124            21.140496             67.074380    0.997178
# std      0.011266             7.257339             22.350533    0.001265
# ...

# %%
# Menampilkan distribusi dari cluster1
plot_cluster(cluster1)

# %% [markdown]
# Ciri-ciri dari Cluster 1 ialah sebagai berikut :
#
# 1. Kualitas terbanyak : 5.
# 2. Density rata-rata : 0.997178
# 3. pH rata-rata : 3.3 (diantara rentang 3.0-3.6).
# 4. Alcohol rata-rata : 9.8 (diantara rentang 9.0-12.0).

# %% [markdown]
# #### Cluster 2

# %%
# Menampilkan deskripsi statistik dari cluster 2
cluster2.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count     256.000000        256.000000   256.000000      256.000000
# mean        7.658203          0.615508     0.131094        2.070898
# std         0.922704          0.136402     0.111473        0.414283
# min         5.200000          0.320000     0.000000        1.200000
# 25%         7.000000          0.520000     0.020000        1.800000
# 50%         7.500000          0.610000     0.115000        2.000000
# 75%         8.225000          0.695000     0.220000        2.300000
# max        10.200000          1.005000     0.470000        3.600000
#
#         chlorides  free sulfur dioxide  total sulfur dioxide     density  \
# count  256.000000           256.000000            256.000000  256.000000
# mean     0.079336             9.707031             28.171875    0.996616
# std      0.012146             4.517950             13.328495    0.001084
# ...

# %%
# Menampilkan deskripsi statistik dari cluster 2
plot_cluster(cluster2)

# %% [markdown]
# Ciri-ciri dari Cluster 2 ialah sebagai berikut :
#
# 1. Kualitas terbanyak : 5.
# 2. Density rata-rata : 0.996616.
# 3. pH rata-rata : 3.3 (diantara rentang 3.0-3.6).
# 4. Alcohol rata-rata : 9.8 (diantara rentang 9.0-11.6).

# %% [markdown]
# #### Cluster 3

# %%
# Menampilkan deskripsi statistik dari cluster 3
cluster3.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count      99.000000         99.000000    99.000000       99.000000
# mean       10.360606          0.392828     0.481212        2.368182
# std         1.087388          0.103288     0.111349        0.523648
# min         7.800000          0.180000     0.240000        1.400000
# 25%         9.550000          0.317500     0.405000        2.000000
# 50%        10.400000          0.390000     0.480000        2.300000
# 75%        11.400000          0.465000     0.555000        2.700000
# max        12.000000          0.670000     0.730000        3.600000
#
#        chlorides  free sulfur dioxide  total sulfur dioxide    density  \
# count  99.000000            99.000000             99.000000  99.000000
# mean    0.080657            10.161616             27.909091   0.998076
# std     0.013773             6.058738             12.968636   0.001238
# ...

# %%
# Menampilkan distribusi dari cluster3
plot_cluster(cluster3)

# %% [markdown]
# Ciri-ciri dari Cluster 3 ialah sebagai berikut :
#
# 1. Kualitas terbanyak : 6.
# 2. Density rata-rata : 0.998076.
# 3. pH rata-rata : 3.1 (diantara rentang 3.0-3.4).
# 4. Alcohol rata-rata : 10.4 (diantara rentang 8.7-12.5).

# %% [markdown]
# #### Cluster 4

# %%
# Menampilkan deskripsi statistik dari cluster 4
cluster4.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count      96.000000         96.000000    96.000000       96.000000
# mean        6.690625          0.625573     0.087813        2.158854
# std         0.697979          0.142941     0.093968        0.383199
# min         5.200000          0.340000     0.000000        1.500000
# 25%         6.200000          0.530000     0.010000        1.900000
# 50%         6.600000          0.612500     0.070000        2.100000
# 75%         7.100000          0.715000     0.120000        2.400000
# max         8.400000          0.980000     0.400000        3.600000
#
#        chlorides  free sulfur dioxide  total sulfur dioxide    density  \
# count  96.000000            96.000000             96.000000  96.000000
# mean    0.068760            18.052083             37.114583   0.994583
# std     0.013062             9.506086             19.126653   0.001092
# ...

# %%
# Menampilkan distribusi dari cluster 4
plot_cluster(cluster4)

# %% [markdown]
# Ciri-ciri dari Cluster 4 ialah sebagai berikut :
#
# 1. Kualitas terbanyak : 6.
# 2. Density rata-rata : 0.994583.
# 3. pH rata-rata : 3.4 (diantara rentang 3.2-3.6).
# 4. Alcohol rata-rata : 11.5 (diantara rentang 9.5-13.0).

# %% [markdown]
# #### Cluster 5

# %%
# Menampilkan deskripsi statistik dari cluster 5
cluster5.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count      94.000000         94.000000    94.000000       94.000000
# mean        8.195745          0.337872     0.383085        2.025532
# std         1.015463          0.087420     0.104491        0.308895
# min         6.100000          0.120000     0.000000        1.300000
# 25%         7.500000          0.291250     0.330000        1.800000
# 50%         8.200000          0.330000     0.400000        2.000000
# 75%         8.900000          0.380000     0.440000        2.300000
# max        10.300000          0.590000     0.650000        2.700000
#
#        chlorides  free sulfur dioxide  total sulfur dioxide    density  \
# count  94.000000            94.000000             94.000000  94.000000
# mean    0.068904            12.244681             27.734043   0.995089
# std     0.013747             7.296613             16.085240   0.000794
# ...

# %%
# Menampilkan distribusi dari cluster 5
plot_cluster(cluster5)

# %% [markdown]
# Ciri-ciri dari Cluster 5 ialah sebagai berikut :
#
# 1. Kualitas terbanyak : 5 dan 6.
# 2. Density rata-rata : 0.995089.
# 3. pH rata-rata : 3.3 (diantara rentang 3.1-3.6).
# 4. Alcohol rata-rata : 11.4 (diantara rentang 9.6-12.8).

# %% [markdown]
# ## Deployment

# %% [markdown]
# Dari tahap-tahap sebelumnya, dapat diketahui algoritma **Birch** memiliki performa yang lebih baik, bila dibandingkan dengan AlgomerativeClustering dan K-Means.

# %%
# Visualisasi scatter plot pada algoritma Birch
br.plot_3d(cols[0],cols[1],cols[2])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
